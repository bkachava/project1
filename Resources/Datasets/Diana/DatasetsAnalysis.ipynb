# %% [markdown]
# Obtain general dataset analysis for assigned databases

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
#First, Estaciones
#cwd=os.getcwd()
#print(cwd)
Bas = "./recorridos_realizados_2018.csv"
#Bas_df=pd.dataframe(Bas)
Bas_reg = pd.read_csv(Bas)
Bas_reg.head()
# Out:
#    bici_id_usuario bici_Fecha_hora_retiro            bici_tiempo_uso  \
# 0             5453    2018-01-01 00:08:05  0 days 00:19:53.000000000
# 1              673    2018-01-01 00:18:05  0 days 00:26:19.000000000
# 2           179119    2018-01-01 00:20:14  0 days 00:27:39.000000000
# 3           400147    2018-01-01 00:20:22  0 days 00:48:51.000000000
# 4           400156    2018-01-01 00:20:31  0 days 00:49:27.000000000
#
#   bici_nombre_estacion_origen  bici_estacion_origen  \
# 0                     Uruguay                    45
# 1                     Posadas                   189
# 2          Hospital Rivadavia                    50
# 3              Macacha Güemes                   111
# 4              Macacha Güemes                   111
#
#   bici_nombre_estacion_destino  bici_estacion_destino bici_sexo  bici_edad
# 0              Virrey Cevallos                    183         M         45
# 1                Guardia Vieja                    110         M         61
# ...

# %%
Bas1=Bas_reg['bici_id_usuario'].count()
Bas1
# Out:
# 2619968

# %%
Bas2=Bas_reg.groupby(['bici_id_usuario']).count()
Bas2
# Out:
#                  bici_Fecha_hora_retiro  bici_tiempo_uso  \
# bici_id_usuario
# 8                                     8                8
# 11                                    1                0
# 12                                    1                1
# 16                                    3                3
# 17                                    3                3
# 20                                    7                7
# 21                                    1                1
# 24                                    3                3
# 25                                  118              117
# 31                                   10               10
# 32                                    1                1
# 33                                    3                2
# 34                                   43               43
# 36                                    9                9
# 42                                    1                1
# ...

# %%
Ecobici = ("./estaciones_de_ecobici_fr.csv")
#Bas_df=pd.dataframe(Bas)
Ecobici_Estaciones = pd.read_csv(Ecobici,error_bad_lines=False)
Ecobici_Estaciones
# Out:
#       ID                                             Nombre  \
# 0    443                       443 BRUNO TRAVEN-GOLONDRINAS
# 1    416                               416 RECREO-PARROQUÍA
# 2    440                  440 REAL DE MAYORAZGO-PUENTE XOCO
# 3     12                           12 RIO LERMA-VILLALONGIN
# 4     41                     41 REFORMA-AV. DE LA REPUBLICA
# 5     57                         57 CUERNAVACA-JUAN ESCUTIA
# 6     74                              74 NUEVO LEON-OZULAMA
# 7     70                         70 PARQUE MEXICO-MICHOACAN
# 8     86                            86 SULLIVAN-INSURGENTES
# 9    232                              232 TAINE-RUBEN DARÍO
# 10   250                        250 DARWIN-MARIANO ESCOBEDO
# 11   261          261 PASEO DE LA REFORMA - RÍO DE LA PLATA
# 12   264             264 HÉROES FERROCARRILEROS-AV. CENTRAL
# 13   273               273 LUIS DONALDO COLOSIO-AV. CENTRAL
# 14   277               277 AMPLIACIÓN TONALÁ-OBRERO MUNDIAL
# ...
